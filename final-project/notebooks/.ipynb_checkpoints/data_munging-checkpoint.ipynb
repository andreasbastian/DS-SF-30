# %%
import os
import dateutil
import numpy as np


#set up pandas
import pandas as pd
pd.set_option('display.max_rows', 20)
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_columns', 20)

#set up plotting
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline
plt.style.use('ggplot')

# %% [markdown]
# ## Introduction and Goals:
# This notebook cleans and analyses the directory data of the American Foundry Society (AFS).
#
# Goals of the analysis:
# - Establish an understanding of the demographics of size, geography, and processes
# - Explore the value-add engineering that different foundries offer
# - Explore what opportunities are afforded by size of foundries

# %%
df = pd.read_csv(os.path.join('..', 'datasets', 'AFS_full.csv'))
zipTable = pd.read_csv(os.path.join('..', 'datasets', 'free-zipcode-database-Primary.csv'))
df
# Out:
#                             Address  \
# 0                    630 E Green St
# 1                 12202 Newburgh Rd
# 2                 12238 Newburgh Rd
# 3                    5512 Scotch Rd
# 4               2103 Stokke Parkway
# 5               434 Margaret Street
# 6              5297 State Route 487
# 7               2121 Bristol Ave NW
# 8                     3040 Osler St
# 9                   13040 Foulks Ln
# ..                              ...
# 325                     202 Vine St
# 326                    500 Broadway
# 327       1410 W Lark Industrial Dr
# 328             1800 Innovation Way
# 329  3808 North Sullivan Rd Bldg #1
# 330                   726 Stone Ave
# 331                  8910 W Main St
# 332                   710 Fourth St
# 333                   338 S Main St
# 334                   252 N West St
#
#                                      Casting Processes  Casting Size (From)  \
# 0    Air-Set/Nobake,Gas-Hardened/Coldbox,Green Sand...                  0.0
# 1                                                  NaN                  NaN
# 2                                                  NaN                  NaN
# 3    Air-Set/Nobake,Gas-Hardened/Coldbox,Green Sand...                  1.0
# 4    Air-Set/Nobake,Gas-Hardened/Coldbox,Green Sand...                  2.0
# 5                     Permanent Mold-Gravity/Tilt Pour                  NaN
# 6    Gas-Hardened/Coldbox,Green Sand-Horizontally P...                  1.0
# 7                            Lost Foam (EPC/Full Mold)                500.0
# 8                  Air-Set/Nobake,Gas-Hardened/Coldbox                  5.0
# 9        Air-Set/Nobake,Green Sand-Horizontally Parted               5000.0
# ..                                                 ...                  ...
# 325                                                NaN                  NaN
# 326                                     Air-Set/Nobake                150.0
# 327                                         Diecasting                  0.1
# 328                                 Investment Casting                  0.0
# 329  Air-Set/Nobake,Gas-Hardened/Coldbox,Green Sand...                  0.0
# 330  Air-Set/Nobake,Gas-Hardened/Coldbox,Green Sand...                  1.0
# 331                                         Diecasting                  0.0
# 332     Air-Set/Nobake,Gas-Hardened/Coldbox,Shell Mold                  1.0
# 333  Air-Set/Nobake,Gas-Hardened/Coldbox,Green Sand...                  0.0
# 334      Air-Set/Nobake,Green Sand-Horizontally Parted                  1.0
#
#      Casting Size (To)            City Country  Employees             Fax  \
# 0                400.0     Bensenville      US       84.0  (630) 766-3307
# 1                  NaN         Livonia      US        NaN  (734) 464-6314
# 2                  NaN         Livonia      US        NaN  (734) 464-6314
# 3               1500.0          Vassar      US       50.0  (989) 823-7214
# 4               2000.0       Menomonie      US       40.0  (715) 235-1398
# 5                  NaN    Lawrenceburg      US       90.0  (812) 537-5693
# 6                250.0          Benton      US      265.0  (570) 925-6929
# 7              50000.0    Grand Rapids      US      100.0  (616) 453-1033
# 332                             TEXALOY FOUNDRY CO INC  (830) 393-4066
# 333                             WILLMAN INDUSTRIES INC  (920) 668-8526
# 334                                      XENIA FOUNDRY  (937) 372-4481
#
#        State                              Value Added Processes  \
# 0         IL  Engineering and Design,Finish Machining,Heat T...
# 1         MI  Engineering and Design,Heat Treat,Prototyping,...
# 2         MI                                         Heat Treat
# 3         MI  Assembly,Coating,Engineering and Design,Finish...
# 4         WI  Finish Machining,Heat Treat,Painting,Patternma...
# 5         IN  Coating,Engineering and Design,Finish Machinin...
# 6         PA  Engineering and Design,Finish Machining,Heat T...
# 7         MI                                                NaN
# 8    Ontario  Assembly,Engineering and Design,Finish Machini...
# 9         LA  Engineering and Design,Finish Machining,Heat T...
# ..       ...                                                ...
# 325       OH                                                NaN
# 326       PA                             Engineering and Design
# 327       MO  Assembly,Engineering and Design,Finish Machini...
# 328       WI  Assembly,Coating,Engineering and Design,Finish...
# 329       WA  Assembly,Coating,Engineering and Design,Finish...
# 330       AL          Coating,Heat Treat,Painting,Patternmaking
# 331       MN  Assembly,Engineering and Design,Finish Machini...
# 332       TX  Assembly,Coating,Engineering and Design,Finish...
# 333       WI                  Heat Treat,Painting,Patternmaking
# 334       OH      Engineering and Design,Heat Treat,Prototyping
#
#                                                Website         Zip
# 0                                http://www.alubra.com       60106
# 1                        http://www.appliedprocess.com  48150-1046
# 2                        http://www.appliedprocess.com       48150
# 3                            http://www.astechcast.com       48768
# 4                       http://www.badgerironworks.com       54751
# 5                    http://www.batesvilleproducts.com       47025
# 6                         http://www.bentonfoundry.com       17814
# 7                        http://www.betzindustries.com       49504
# 8    http://bradken.com/our-business/engineered-pro...     N5Y 1V3
# 9    http://bradken.com/our-business/engineered-pro...       70422
# ..                                                 ...         ...
# 325                             http://www.oscoind.com       45662
# 326                     http://www.pennmarcastings.com       17331
# 327                  http://www.productioncastings.com  63026-4340
# 328                           http://www.signicast.com       53027
# 329                   http://www.spokaneindustries.com       99216
# 330                    http://www.talladegafoundry.com       35161
# 331                    http://www.tech-die-casting.com  55987-1962
# 332                             http://www.texaloy.com       78114
# 333                          http://www.willmanind.com       53013
# 334                        http://www.xeniafoundry.com       45385
#
# [335 rows x 15 columns]

# %% [markdown]
# ## Step One:  Clean the Data
# The data has a
#
# |Feature|Type|Description|
# |---|---|---|
# |Name|String|Name of the company|
# |Address|String|Street address of the company|
# |City|String|City|
# |State|String|State|
# |Zip|Int|Zip code|
# |Country|String|Country|
# |Website|String|Website|
# |Phone|String|Phone number|
# |Fax|String|Fax number|
# |Employees|Int|Number of employees|
# |Casting Size (From)|Float|Smallest casting size serviced by foundry|
# |Casting Size (To)|Float|Largest casting size serviced by foundry|
# |Casting Processes|String|The different processes undertaken by the foundry|
# |Metals|String|The different alloys poured by the foundry|
# |Value Added Processes|String|Value add engineering processes offered by the foundry|
#
# Of these, only a subset are interesting for the analysis:
#
# |Feature|Type|Description|
# |---|---|---|
# |Name|String|Name of the company|
# |Zip|Int|Zip code|
# |State|String|State|
# |Country|String|Country|
# |Employees|Int|Number of employees|
# |Casting Size (From)|Float|Smallest casting size serviced by foundry|
# |Casting Size (To)|Float|Largest casting size serviced by foundry|
# |Casting Processes|String|The different processes undertaken by the foundry|
# |Metals|String|The different alloys poured by the foundry|
# |Value Added Processes|String|Value add engineering processes offered by the foundry|

# %%
df.columns = df.columns.str.replace(' ', '_')
df.columns = df.columns.str.replace('(', '')
df.columns = df.columns.str.replace(')', '')
df.columns = map(str.lower, df.columns)

print "Summary of Null Values:"
print str(df.isnull().sum()) + "\n\n"
print "Summary of Types:"
for i in df:
    print str(i) + "\t" + str(type(i))
# Out:
# Summary of Null Values:
# address                   0
# casting_processes        20
# casting_size_from        68
# casting_size_to          69
# city                      0
# country                   0
# employees                44
# fax                      26
# metals                   13
# name                      0
# phone                     1
# state                     0
# value_added_processes    53
# website                   8
# zip                       0
# dtype: int64
#
#
# Summary of Types:
# address	<type 'str'>
# casting_processes	<type 'str'>
# casting_size_from	<type 'str'>
# casting_size_to	<type 'str'>
# city	<type 'str'>
# country	<type 'str'>
# employees	<type 'str'>
# fax	<type 'str'>
# metals	<type 'str'>
# name	<type 'str'>
# phone	<type 'str'>
# state	<type 'str'>
# value_added_processes	<type 'str'>
# website	<type 'str'>
# zip	<type 'str'>

# %%
#some zip codes are in the format xxxxx-xxxx, whcih won't convert to a numeric value, so we want to drop the last
#five characters of those zip codes
def splitAtDash(x):
    return x.split('-')[0]
df['zip'] = df['zip'].apply(splitAtDash)

# %%
zipFloat = pd.to_numeric(df['zip'], errors='coerce') #this means dropping 11 international zips, which is relatively small
empFloat = pd.to_numeric(df['employees'], errors='coerce')
castingFromFloat = pd.to_numeric(df['casting_size_from'], errors='coerce')
castingToFloat = pd.to_numeric(df['casting_size_to'], errors='coerce')

print "NaNs before to_numeric:  " + str(df['zip'].isnull().sum()) + "\t NaNs after to_numeric:  " + str(zipFloat.isnull().sum())
print "NaNs before to_numeric:  " + str(df['employees'].isnull().sum()) + "\t NaNs after to_numeric:  " + str(empFloat.isnull().sum())
print "NaNs before to_numeric:  " + str(df['casting_size_from'].isnull().sum()) + "\t NaNs after to_numeric:  " + str(castingFromFloat.isnull().sum())
print "NaNs before to_numeric:  " + str(df['casting_size_to'].isnull().sum()) + "\t NaNs after to_numeric:  " + str(castingToFloat.isnull().sum())
# Out:
# NaNs before to_numeric:  0	 NaNs after to_numeric:  11
# NaNs before to_numeric:  44	 NaNs after to_numeric:  44
# NaNs before to_numeric:  68	 NaNs after to_numeric:  68
# NaNs before to_numeric:  69	 NaNs after to_numeric:  69

# %%
zipFloat
# Out:
# 0      60106.0
# 1      48150.0
# 2      48150.0
# 3      48768.0
# 4      54751.0
# 5      47025.0
# 6      17814.0
# 7      49504.0
# 8          NaN
# 9      70422.0
#         ...
# 325    45662.0
# 326    17331.0
# 327    63026.0
# 328    53027.0
# 329    99216.0
# 330    35161.0
# 331    55987.0
# 332    78114.0
# 333    53013.0
# 334    45385.0
# Name: zip, dtype: float64
